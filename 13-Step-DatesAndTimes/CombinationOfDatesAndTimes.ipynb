# %% [markdown]
# # Adding time to the mix

# %%
from datetime import datetime

dt = datetime(2017, 10, 1, 15,26,26)

print(dt.isoformat())
# Out:
# 2017-10-01T15:26:26

# %%
import pandas as pd

onebike_datetimes = pd.read_csv('data/capital-onebike.csv', date_parser=['Start date','End date'])

onebike_datetimes.head()
# Out:
# C:\Users\CIRO\AppData\Local\Temp\ipykernel_15480\4219331934.py:3: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   onebike_datetimes = pd.read_csv('data/capital-onebike.csv', date_parser=['Start date','End date'])
#             Start date             End date  Start station number  \
# 0  2017-10-01 15:23:25  2017-10-01 15:26:26                 31038
# 1  2017-10-01 15:42:57  2017-10-01 17:49:59                 31036
# 2  2017-10-02 06:37:10  2017-10-02 06:42:53                 31036
# 3  2017-10-02 08:56:45  2017-10-02 09:18:03                 31037
# 4  2017-10-02 18:23:48  2017-10-02 18:45:05                 31295
#
#                           Start station  End station number  \
# 0                  Glebe Rd & 11th St N               31036
# 1         George Mason Dr & Wilson Blvd               31036
# 2         George Mason Dr & Wilson Blvd               31037
# 3  Ballston Metro / N Stuart & 9th St N               31295
# 4                     Potomac & M St NW               31230
#
#                             End station Bike number Member type
# 0         George Mason Dr & Wilson Blvd      W20529      Member
# 1         George Mason Dr & Wilson Blvd      W20529      Casual
# 2  Ballston Metro / N Stuart & 9th St N      W20529      Member
# 3                     Potomac & M St NW      W20529      Member
# 4         Metro Center / 12th & G St NW      W20529      Member

# %%
trip_counts = {'AM': 0, 'PM': 0}

for trip in onebike_datetimes:
    
    if trip['Start'].hour < 12:
        trip_counts['AM'] +=1
    else:
        trip_counts['PM'] +=1
print(trip_counts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 trip_counts = {'AM': 0, 'PM': 0}
#       3 for trip in onebike_datetimes:
# ----> 4     if trip['Start date'].hour < 12:
#       5         trip_counts['AM'] +=1
#       6     else:
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# # Printing and parsing datetime

# %%
dt = datetime(2017,12,30,15,19,13)
print(dt.strftime('%Y-%m-%d'))
