# %% [markdown]
# # Membership constraints

# %%
import pandas as pd

# %%
categories = pd.read_csv("data/categories.csv")
airlines = pd.read_csv("data/airlines.csv")

# %%
categories
# Out:
#       cleanliness           safety          satisfaction
# 0           Clean          Neutral        Very satisfied
# 1         Average        Very safe               Neutral
# 2  Somewhat clean    Somewhat safe    Somewhat satisfied
# 3  Somewhat dirty      Very unsafe  Somewhat unsatisfied
# 4           Dirty  Somewhat unsafe      Very unsatisfied

# %%
print('Cleanliness: ', airlines['cleanliness'].unique(), "\n")
print('Safety: ', airlines['safety'].unique(), "\n")
print('Satisfaction: ', airlines['satisfaction'].unique(), "\n")
# Out:
# Cleanliness:  ['Somewhat clean' 'Average' 'Clean' 'Unacceptable' 'Somewhat dirty'
#  'Dirty']
#
# Safety:  ['Very unsafe' 'Somewhat safe' 'Somewhat unsafe' 'Neutral' 'Very safe']
#
# Satisfaction:  ['Somewhat unsatisfied' 'Very unsatisfied' 'Somewhat satisfied' 'Neutral'
#  'Very satisfied']

# %%
cat_clean = set(airlines['cleanliness']).difference(categories['cleanliness'])
cat_clean_rows = airlines['cleanliness'].isin(cat_clean)
airlines[cat_clean_rows]
# Out:
#         id       day        airline destination            dest_region  \
# 4     1004  Thursday         ALASKA      DEST_4                 Europe
# 17    1017   Tuesday  CHINA EASTERN     DEST_17                    eur
# 33    1033  Saturday         UNITED     DEST_33            Middle East
# 37    1037    Friday  CHINA EASTERN     DEST_37            middle east
# 40    1040  Thursday      SOUTHWEST     DEST_40  Australia/New Zealand
# ...    ...       ...            ...         ...                    ...
# 2431  3431  Saturday         ALASKA   DEST_2431             Midwest US
# 2433  3433    Friday         ALASKA   DEST_2433  Central/South America
# 2435  3435  Saturday          DELTA   DEST_2435            Middle East
# 2451  3451    Monday          DELTA   DEST_2451                   Asia
# 2469  3469   Tuesday  CHINA EASTERN   DEST_2469          Canada/Mexico
#
#        dest_size boarding_area   dept_time  wait_min   cleanliness  \
# 4       Hub         Gates 1-12  2018-12-31     587.8  Unacceptable
# 17         Large   Gates 50-59  2018-12-31     477.6  Unacceptable
# 33    Small        Gates 50-59  2018-12-31     296.7  Unacceptable
# 37        Medium    Gates 1-12  2018-12-31      87.3  Unacceptable
# 40        Medium  Gates 91-102  2018-12-31     433.7  Unacceptable
# ...          ...           ...         ...       ...           ...
# 2431       Large   Gates 40-48  2018-12-31      71.9  Unacceptable
# 2433       Large   Gates 20-39  2018-12-31     438.6  Unacceptable
# 2435         Hub   Gates 20-39  2018-12-31     587.6  Unacceptable
# 2451         Hub  Gates 91-102  2018-12-31     561.7  Unacceptable
# 2469       Small  Gates 91-102  2018-12-31     368.1  Unacceptable
#
#                safety        satisfaction
# 4       Somewhat safe    Very unsatisfied
# 17        Very unsafe      Very satisfied
# 33    Somewhat unsafe             Neutral
# 37          Very safe      Very satisfied
# 40          Very safe      Very satisfied
# ...               ...                 ...
# 2431        Very safe    Very unsatisfied
# 2433      Very unsafe  Somewhat satisfied
# 2435    Somewhat safe      Very satisfied
# 2451    Somewhat safe  Somewhat satisfied
# 2469          Neutral      Very satisfied
#
# [426 rows x 12 columns]

# %%
airlines[~cat_clean_rows]
# Out:
#         id        day        airline destination            dest_region  \
# 0     1000   Saturday          DELTA      DEST_0          Canada/Mexico
# 1     1001     Friday        JETBLUE      DEST_1  Australia/New Zealand
# 2     1002    Tuesday        JETBLUE      DEST_2                West US
# 3     1003  Wednesday    UNITED INTL      DEST_3                West US
# 5     1005     Monday  CHINA EASTERN      DEST_5            Middle East
# ...    ...        ...            ...         ...                    ...
# 2472  3472    Tuesday         ALASKA   DEST_2472            Middle East
# 2473  3473     Sunday      SOUTHWEST   DEST_2473  Central/South America
# 2474  3474    Tuesday       AMERICAN   DEST_2474                West US
# 2475  3475     Friday    UNITED INTL   DEST_2475             Midwest US
# 2476  3476   Saturday         UNITED   DEST_2476                East US
#
#         dest_size boarding_area   dept_time  wait_min     cleanliness  \
# 0             Hub  Gates 91-102  2018-12-31     155.7  Somewhat clean
# 1          Medium   Gates 40-48  2018-12-31     480.3         Average
# 2           Large    Gates 1-12  2018-12-31     533.5           Clean
# 3             Hub  Gates 91-102  2018-12-31     263.4  Somewhat clean
# 5        Hub        Gates 40-48  2018-12-31     101.2  Somewhat dirty
# ...           ...           ...         ...       ...             ...
# 2472       Medium  Gates 91-102  2018-12-31     499.4           Clean
# 2473        Large    Gates 1-12  2018-12-31      58.4         Average
# 2474       Medium   Gates 50-59  2018-12-31     377.8           Dirty
# 2475       Medium   Gates 20-39  2018-12-31     155.2  Somewhat dirty
# 2476  Medium        Gates 40-48  2018-12-31     596.8           Dirty
#
#                safety          satisfaction
# 0         Very unsafe  Somewhat unsatisfied
# 1       Somewhat safe      Very unsatisfied
# 2         Very unsafe  Somewhat unsatisfied
# 3       Somewhat safe  Somewhat unsatisfied
# 5     Somewhat unsafe  Somewhat unsatisfied
# ...               ...                   ...
# 2472      Very unsafe      Very unsatisfied
# 2473        Very safe               Neutral
# 2474      Very unsafe        Very satisfied
# 2475          Neutral               Neutral
# 2476  Somewhat unsafe               Neutral
#
# [2051 rows x 12 columns]

# %% [markdown]
# # Categorical variables

# %%
airlines['dest_size'].unique()
# Out:
# array(['Hub', 'Medium', 'Large', '    Hub', 'Hub     ', 'Large     ',
#        'Medium     ', 'Small     ', '    Large', 'Small', '    Medium',
#        '    Small'], dtype=object)

# %%
airlines['dest_region'].unique()
# Out:
# array(['Canada/Mexico', 'Australia/New Zealand', 'West US', 'Europe',
#        'Middle East', 'middle east', 'Asia', 'eur', 'EAST US',
#        'Central/South America', 'East US', 'Midwest US'], dtype=object)

# %%
airlines['dest_region'] = airlines['dest_region'].str.lower()
airlines['dest_region'] = airlines['dest_region'].replace({'eur':'europe'})
airlines['dest_size'] = airlines['dest_size'].str.strip()

# %%
import numpy as np
label_ranges = [0, 60, 180, np.inf]
label_names = ['short', 'medium', 'long']

# %%
airlines['wait_type'] = pd.cut(airlines['wait_min'], bins = label_ranges, labels = label_names)

# %%
mappings = {'Monday':'weekday', 'Tuesday':'weekday', 'Wednesday': 'weekday', 
            'Thursday': 'weekday', 'Friday': 'weekday', 
            'Saturday': 'weekend', 'Sunday': 'weekend'}
airlines['day_week'] = airlines['day'].replace(mappings)
